# %%
import openpyxl
import pandas as pd

# %%
wb = openpyxl.load_workbook('data/CricPredictor.xlsx')

# %%
teams = [
    'Delhi Capitals',
    'Csk',
    'Gujarat Titans',
    'Kolkata Night Riders',
    'Lucknow Super Giants',
    'Mumbai Indians',
    'Punjab Kings',
    'Rajasthan Royals',
    'RCB',
    'Sunrisers Hyderabed'
]

# %%
df = pd.DataFrame(columns=['player_name','position','team_name'])

# %%
for team in teams:
    sheet = wb[team]
    for row in sheet.iter_rows(values_only=True):
        df = df.append({'player_name':row[0],'position':row[1],'team_name':team},ignore_index=True)

# %%
df.to_csv('data/players.csv')

# %%
batter_info = pd.read_csv('data/international_batter_info.csv',index_col=0)
bowler_info = pd.read_csv('data/international_bowler_info.csv',index_col=0)
match_links = pd.DataFrame(columns=['city','date','match_link'])
matches = set()

# %%
match_links.head()
# Out:
# Empty DataFrame
# Columns: [city, date, match_link]
# Index: []

# %%
for _,row in batter_info.iterrows():
    if row['match_link'] not in matches:
        matches.add(row['match_link'])
        match_links = match_links.append({'match_link':row['match_link'],'city':row['ground'],'date':row['date']},ignore_index=True)
# Out:
# C:\Users\Tharang\AppData\Local\Temp\ipykernel_31988\970283594.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   match_links = match_links.append({'match_link':row['match_link'],'city':row['ground'],'date':row['date']},ignore_index=True)
# C:\Users\Tharang\AppData\Local\Temp\ipykernel_31988\970283594.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   match_links = match_links.append({'match_link':row['match_link'],'city':row['ground'],'date':row['date']},ignore_index=True)
# C:\Users\Tharang\AppData\Local\Temp\ipykernel_31988\970283594.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   match_links = match_links.append({'match_link':row['match_link'],'city':row['ground'],'date':row['date']},ignore_index=True)
# ...

# %%
for _,row in bowler_info.iterrows():
    if row['match_link'] not in matches:
        matches.add(row['match_link'])
        match_links = match_links.append({'match_link':row['match_link'],'city':row['ground'],'date':row['date']},ignore_index=True)
# Out:
# C:\Users\Tharang\AppData\Local\Temp\ipykernel_31988\4101270120.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   match_links = match_links.append({'match_link':row['match_link'],'city':row['ground'],'date':row['date']},ignore_index=True)
# C:\Users\Tharang\AppData\Local\Temp\ipykernel_31988\4101270120.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   match_links = match_links.append({'match_link':row['match_link'],'city':row['ground'],'date':row['date']},ignore_index=True)
# C:\Users\Tharang\AppData\Local\Temp\ipykernel_31988\4101270120.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   match_links = match_links.append({'match_link':row['match_link'],'city':row['ground'],'date':row['date']},ignore_index=True)
# ...

# %%
match_links.to_csv('data/match_links.csv')
